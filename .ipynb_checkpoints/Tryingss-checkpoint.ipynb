# %% [markdown]
# # Recommender System based on Review Book in E-commerce Using word2vec Algorithm
#
#
# 1. Yolanda R.M Manurung (12S17017)
# 2. Stella Sitinjak      (12S17027)
# 3. Ekis Naomi Lasma     (12S17059)
#
#
# ### Dataset
# Data yang digunakan pada proyek ini berasal dari kaggle (https://www.kaggle.com/gapple/goodreads-book-reviews-20k)

# %% [markdown]
# ## 1. Load Data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#import library yang akan digunakan
import pandas as pd
import re
import gensim
import string
from gensim.models import Word2Vec
import numpy as np
from scipy import linalg
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet

# %%
#load dataset Goodreads buku dan menampilkan 5 data teratas
data = pd.read_csv("./all_data.csv")
print ('Jumlah data =', len(data))
data.head()
# Out:
# Jumlah data = 21559
#                   book_title                       Book_series  \
# 0  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 1  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 2  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 3  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 4  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
#
#                                      book_series_url  \
# 0  https://www.goodreads.com/series/104014-a-cour...
# 1  https://www.goodreads.com/series/104014-a-cour...
# 2  https://www.goodreads.com/series/104014-a-cour...
# 3  https://www.goodreads.com/series/104014-a-cour...
# 4  https://www.goodreads.com/series/104014-a-cour...
#
#                                           book_image  \
# 0  https://images.gr-assets.com/books/1485528243l...
# 1  https://images.gr-assets.com/books/1485528243l...
# 2  https://images.gr-assets.com/books/1485528243l...
# 3  https://images.gr-assets.com/books/1485528243l...
# 4  https://images.gr-assets.com/books/1485528243l...
#
#                                       book_image_url  book_rating  \
# 0  https://www.goodreads.com/book/photo/23766634-...         4.51
# 1  https://www.goodreads.com/book/photo/23766634-...         4.51
# 2  https://www.goodreads.com/book/photo/23766634-...         4.51
# 3  https://www.goodreads.com/book/photo/23766634-...         4.51
# 4  https://www.goodreads.com/book/photo/23766634-...         4.51
#
#      book_author                                         author_url  \
# 0  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 1  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 2  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 3  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 4  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
#
#                                       genre                 reviewer_name  \
# 0  Fantasy, Romance, Young Adult, New Adult                          emma
# 1  Fantasy, Romance, Young Adult, New Adult  Em (RunawayWithDreamthieves)
# 2  Fantasy, Romance, Young Adult, New Adult     Cait • A Page with a View
# 3  Fantasy, Romance, Young Adult, New Adult                Natalie Monroe
# 4  Fantasy, Romance, Young Adult, New Adult                     Emily May
#
#                                         reviewer_url  \
# 0  https://www.goodreads.com/user/show/32879029-emma
# 1  https://www.goodreads.com/user/show/42130592-e...
# 2  https://www.goodreads.com/user/show/47412532-c...
# 3  https://www.goodreads.com/user/show/6688207-na...
# 4  https://www.goodreads.com/user/show/4622890-em...
#
#                                       reviewer_image  \
# 0  https://images.gr-assets.com/users/1520568130p...
# 1  https://images.gr-assets.com/users/1538507799p...
# 2  https://images.gr-assets.com/users/1523134490p...
# 3  https://images.gr-assets.com/users/1339730817p...
# 4  https://images.gr-assets.com/users/1528390751p...
#
#                                   reviewer_image_url  \
# 0  https://www.goodreads.com/user/show/32879029-emma
# 1  https://www.goodreads.com/user/show/42130592-e...
# 2  https://www.goodreads.com/user/show/47412532-c...
# 3  https://www.goodreads.com/user/show/6688207-na...
# 4  https://www.goodreads.com/user/show/4622890-em...
#
#                                               review  ID
# 0  202.\r\nThat’s the number of times that the wo...   1
# 1  I need a black silk robe and a balcony to wear...   2
# 2  THIS BOOK TOTALLY WRECKED ME. In the best poss...   3
# 3  3.75 stars\r\n"Rhys stepped off the stairs and...   4
# 4  I wish so much that I could tell you I loved t...   5

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# Tahap awal sebelum preprocessing yaitu melakukan preparation untuk pengecekan data noise dan dirty. Tahap yang dilakukan adalah pengecekan null value dan duplicate value

# %% [markdown]
# ### Drop Null Value

# %%
#pengecekan nilai null pada data
data.isnull().sum()
# Out:
# book_title                0
# Book_series           12779
# book_series_url       12779
# book_image                2
# book_image_url            2
# book_rating               0
# book_author               0
# author_url                0
# genre                   121
# reviewer_name            25
# reviewer_url             25
# reviewer_image           25
# reviewer_image_url       25
# review                  742
# ID                        0
# dtype: int64

# %%
#penghapusan null value dengan menggunakan fillna
data['Book_series'] = data['Book_series'].fillna(data['Book_series'].mode().iloc[0])
data['book_series_url'] = data['book_series_url'].fillna(data['book_series_url'].mode().iloc[0])
data['book_image'] = data['book_image'].fillna(data['book_image'].mode().iloc[0])
data['book_image_url'] = data['book_image_url'].fillna(data['book_image_url'].mode().iloc[0])
data['genre'] = data['genre'].fillna(data['genre'].mode().iloc[0])
data['reviewer_name'] = data['reviewer_name'].fillna(data['reviewer_name'].mode().iloc[0])
data['reviewer_url'] = data['reviewer_url'].fillna(data['reviewer_url'].mode().iloc[0])
data['reviewer_image'] = data['reviewer_image'].fillna(data['reviewer_image'].mode().iloc[0])
data['reviewer_image_url'] = data['reviewer_image_url'].fillna(data['reviewer_image_url'].mode().iloc[0])
data['review'] = data['review'].fillna(data['review'].mode().iloc[0])

# %%
#pengecekan data setelah drop null value
data.isnull().sum()
# Out:
# book_title            0
# Book_series           0
# book_series_url       0
# book_image            0
# book_image_url        0
# book_rating           0
# book_author           0
# author_url            0
# genre                 0
# reviewer_name         0
# reviewer_url          0
# reviewer_image        0
# reviewer_image_url    0
# review                0
# ID                    0
# dtype: int64

# %% [markdown]
# ### Drop Duplicate Value

# %%
#pengecekan duplicate value 
data.duplicated().sum()
# Out:
# 0

# %%
#menampilkan 5 data teratas yang sudah di cek duplicate value
data['book_title'].drop_duplicates(keep=False,inplace=True)
data.head()
# Out:
#                   book_title                       Book_series  \
# 0  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 1  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 2  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 3  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
# 4  A Court of Wings and Ruin  (A Court of Thorns and Roses #3)
#
#                                      book_series_url  \
# 0  https://www.goodreads.com/series/104014-a-cour...
# 1  https://www.goodreads.com/series/104014-a-cour...
# 2  https://www.goodreads.com/series/104014-a-cour...
# 3  https://www.goodreads.com/series/104014-a-cour...
# 4  https://www.goodreads.com/series/104014-a-cour...
#
#                                           book_image  \
# 0  https://images.gr-assets.com/books/1485528243l...
# 1  https://images.gr-assets.com/books/1485528243l...
# 2  https://images.gr-assets.com/books/1485528243l...
# 3  https://images.gr-assets.com/books/1485528243l...
# 4  https://images.gr-assets.com/books/1485528243l...
#
#                                       book_image_url  book_rating  \
# 0  https://www.goodreads.com/book/photo/23766634-...         4.51
# 1  https://www.goodreads.com/book/photo/23766634-...         4.51
# 2  https://www.goodreads.com/book/photo/23766634-...         4.51
# 3  https://www.goodreads.com/book/photo/23766634-...         4.51
# 4  https://www.goodreads.com/book/photo/23766634-...         4.51
#
#      book_author                                         author_url  \
# 0  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 1  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 2  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 3  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
# 4  Sarah J. Maas  https://www.goodreads.com/author/show/3433047....
#
#                                       genre                 reviewer_name  \
# 0  Fantasy, Romance, Young Adult, New Adult                          emma
# 1  Fantasy, Romance, Young Adult, New Adult  Em (RunawayWithDreamthieves)
# 2  Fantasy, Romance, Young Adult, New Adult     Cait • A Page with a View
# 3  Fantasy, Romance, Young Adult, New Adult                Natalie Monroe
# 4  Fantasy, Romance, Young Adult, New Adult                     Emily May
#
#                                         reviewer_url  \
# 0  https://www.goodreads.com/user/show/32879029-emma
# 1  https://www.goodreads.com/user/show/42130592-e...
# 2  https://www.goodreads.com/user/show/47412532-c...
# 3  https://www.goodreads.com/user/show/6688207-na...
# 4  https://www.goodreads.com/user/show/4622890-em...
#
#                                       reviewer_image  \
# 0  https://images.gr-assets.com/users/1520568130p...
# 1  https://images.gr-assets.com/users/1538507799p...
# 2  https://images.gr-assets.com/users/1523134490p...
# 3  https://images.gr-assets.com/users/1339730817p...
# 4  https://images.gr-assets.com/users/1528390751p...
#
#                                   reviewer_image_url  \
# 0  https://www.goodreads.com/user/show/32879029-emma
# 1  https://www.goodreads.com/user/show/42130592-e...
# 2  https://www.goodreads.com/user/show/47412532-c...
# 3  https://www.goodreads.com/user/show/6688207-na...
# 4  https://www.goodreads.com/user/show/4622890-em...
#
#                                               review  ID
# 0  202.\r\nThat’s the number of times that the wo...   1
# 1  I need a black silk robe and a balcony to wear...   2
# 2  THIS BOOK TOTALLY WRECKED ME. In the best poss...   3
# 3  3.75 stars\r\n"Rhys stepped off the stairs and...   4
# 4  I wish so much that I could tell you I loved t...   5

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### Case Folding

# %% [markdown]
# Proses untuk melakukan konversi seluruh karakter ke dalam huruf kecil

# %%
#mengubah huruf kapital menjadi huruf kecil yang ditampung pada parameter "lower"
review = []
for i in range(0, 21559):
    review.append(data["review"][i].casefold())
    
data['lower'] = re

# %% [markdown]
# ### Remove Punctuation

# %%
#menghilangkan tanda baca dan ditampung oleh atribut baru yaitu "no_punc"
review = []
for i in range(0, 21559):
    review.append(data["review"][i].replace(",", "").replace("\n", "").replace("\r", "").replace("---", "").replace('|','').replace("!","").replace("//", "").replace("?","").replace("    ", " ").replace("  "," "))

# %%
reviews = []
for i in review:
    review = re.sub(r'\ by.*? on', "", i)
    review = re.sub(r"\d\.\d", "", review)
    review = re.sub(r"\d+\ [a-z]+\.*\ \d+", "", review)
    review = review.replace(".", " ")
    review = re.sub(r'\  *', " ", review)
    reviews.append(review)

# %%
data["reviews"] = reviews
data["reviews"].head()
# Out:
# 0    202 that’s the number of times that the word “...
# 1    i need a black silk robe and a balcony to wear...
# 2    this book totally wrecked me in the best possi...
# 3    5 stars"rhys stepped off the stairs and took m...
# 4    i wish so much that i could tell you i loved t...
# Name: reviews, dtype: object

# %%
data[["book_title", "book_rating", "genre", "review"]].head()
# Out:
#                   book_title  book_rating  \
# 0  A Court of Wings and Ruin         4.51
# 1  A Court of Wings and Ruin         4.51
# 2  A Court of Wings and Ruin         4.51
# 3  A Court of Wings and Ruin         4.51
# 4  A Court of Wings and Ruin         4.51
#
#                                       genre  \
# 0  Fantasy, Romance, Young Adult, New Adult
# 1  Fantasy, Romance, Young Adult, New Adult
# 2  Fantasy, Romance, Young Adult, New Adult
# 3  Fantasy, Romance, Young Adult, New Adult
# 4  Fantasy, Romance, Young Adult, New Adult
#
#                                               review
# 0  202.\r\nThat’s the number of times that the wo...
# 1  I need a black silk robe and a balcony to wear...
# 2  THIS BOOK TOTALLY WRECKED ME. In the best poss...
# 3  3.75 stars\r\n"Rhys stepped off the stairs and...
# 4  I wish so much that I could tell you I loved t...

# %% [markdown]
# Data yang sudah dilakukan preprocessing akan disimpan menjadi data baru dalam file DataBuku.csv

# %%
new = data[["ID", "book_title", "book_rating", "genre", "reviews"]]
new.to_csv("./DataBuku.csv")

# %%
dataset = pd.read_csv("./Databuku.csv", delimiter=",")
dataset.head()
# Out:
#    Unnamed: 0  ID                 book_title  book_rating  \
# 0           0   1  A Court of Wings and Ruin         4.51
# 1           1   2  A Court of Wings and Ruin         4.51
# 2           2   3  A Court of Wings and Ruin         4.51
# 3           3   4  A Court of Wings and Ruin         4.51
# 4           4   5  A Court of Wings and Ruin         4.51
#
#                                       genre  \
# 0  Fantasy, Romance, Young Adult, New Adult
# 1  Fantasy, Romance, Young Adult, New Adult
# 2  Fantasy, Romance, Young Adult, New Adult
# 3  Fantasy, Romance, Young Adult, New Adult
# 4  Fantasy, Romance, Young Adult, New Adult
#
#                                               review
# 0  202.\r\nThat’s the number of times that the wo...
# 1  I need a black silk robe and a balcony to wear...
# 2  THIS BOOK TOTALLY WRECKED ME. In the best poss...
# 3  3.75 stars\r\n"Rhys stepped off the stairs and...
# 4  I wish so much that I could tell you I loved t...

# %% [markdown]
# ### Tokenization

# %%
from nltk.tokenize import SpaceTokenizer
sTokenizer = SpaceTokenizer()
review_tokens = []
for i in dataset['review']:
    review_tokens.append(sTokenizer.tokenize(i))

# %%
dataset['review_tokens'] = review_tokens
dataset['review_tokens'].head()
# Out:
# 0    [202.\r\nThat’s, the, number, of, times, that,...
# 1    [I, need, a, black, silk, robe, and, a, balcon...
# 2    [THIS, BOOK, TOTALLY, WRECKED, ME., In, the, b...
# 3    [3.75, stars\r\n"Rhys, stepped, off, the, stai...
# 4    [I, wish, so, much, that, I, could, tell, you,...
# Name: review_tokens, dtype: object

# %%
vocab = []
for i in dataset['review_tokens']:
    vocab.append(set(i))

# %%
dataset['review_vocabs'] = vocab
dataset['review_vocabs'].head()
# Out:
# 0    {certain, through, males., SCREAM, innocuous, ...
# 1    {getting, hoo, THAT, respect, fault, feysand,,...
# 2    {getting, gods-given, THAT, certain, possible,...
# 3    {getting, spoiler), up., bored, fandom, Rhys—i...
# 4    {“skin, disappointment, dislike, they/won't, s...
# Name: review_vocabs, dtype: object

# %% [markdown]
# ## 4. Word Embedding with Word2Vec

# %%
word2vec_sg = Word2Vec(sentences=dataset['review_vocabs'],
                       size=100, window=5, min_count=1,
                       workers=4, sg=1, iter=10)

# %%
word2vec_sg.wv.similarity(w1="great",w2="good")
# Out:
# 0.10246074

# %%
w1 = ["great"]
word2vec_sg.wv.most_similar (positive=w1,topn=6)
# Out:
# [('anyone', 0.8913525938987732),
#  ('doing', 0.8805692195892334),
#  ('husband', 0.8777946829795837),
#  ('myself', 0.8772739171981812),
#  ('based', 0.8749492168426514),
#  ('home', 0.853769063949585)]

# %%
w1 = ["good",'fun','great']
w2 = ['bad']
word2vec_sg.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# [('FASCINATING!', 0.7107617855072021),
#  ("Didn't", 0.7081338167190552),
#  ("Lilly's", 0.7040373086929321),
#  ('Witt', 0.7015083432197571),
#  ('lots', 0.6993299126625061),
#  ('times!', 0.6983761191368103),
#  ('fort', 0.6978602409362793),
#  ('adored', 0.6977523565292358),
#  ('shamed', 0.6971397399902344),
#  ('fandoms', 0.6953698992729187)]

# %%
word2vec_sg.wv.similarity(w1="good",w2="good")
# Out:
# 1.0

# %%
dataset['review_vocabs'][0]
# Out:
# {'certain',
#  'through',
#  'males.',
#  'SCREAM',
#  'innocuous',
#  'hate',
#  'Videos',
#  'endlessly',
#  'WHAT',
#  'important',
#  'pages.\r\nExample:',
#  'loooong',
#  'movie',
#  '202.\r\nThat’s',
#  'distract',
#  'NOVEL.\r\nIt',
#  'buy',
#  'amused',
#  'WELL',
#  'use',
#  'war',
#  'Even',
#  'GODDAMN',
#  'Feyre.',
#  'loved',
#  'R',
#  'shady',
#  'money.',
#  'tricks',
#  'quickly!!!',
#  'statistic',
#  'madman',
#  'shows',
#  'used',
#  'grace',
#  'inconsistently',
#  'hell.\r\nCauldron',
#  'ON',
#  'born',
#  'viciously',
#  'be',
#  'coming',
#  'cool',
#  'THEY',
#  'transitioning',
#  'throne!).',
#  'Tamlin',
#  'forum!',
#  'looking',
#  'days.”',
#  'wrestler,',
#  'it.\r\nPlus,',
#  'corrects',
#  'accompanying',
#  'tissue',
#  'interchangeable',
#  'unintentional',
#  'How',
#  'live',
#  'described',
#  'ABOUT',
#  'writes',
#  'pages.',
#  'he’s',
#  'called',
#  'impassioned',
#  'PROP',
#  'angry,',
#  'redeem',
#  'through.\r\nDISCLAIMER',
#  'OCCUPIED',
#  'perfect',
#  'douchey',
#  'whatnot.',
#  'goodbyes',
#  'Zellweger',
#  'missed',
#  'silently',
#  'different',
#  'waiting',
#  'whatever',
#  'doesn’t.',
#  'answer',
#  'forget',
#  'short',
#  'floats',
#  'mentioned',
#  'THINGS\r\nSometimes,',
#  'rather',
#  'banal',
#  'interesting,',
#  'reviewer.',
#  'that.\r\nThere',
#  'don’t',
#  'actual',
#  'hot',
#  'two)',
#  'will',
#  'seasons,',
#  'has',
#  'babysit',
#  'who',
#  'V',
#  'giving',
#  'people',
#  'So',
#  'written.\r\nLET’S',
#  'this',
#  'actually,',
#  'captain',
#  'least',
#  'centuries',
#  'actually',
#  'we’ve',
#  'political',
#  'eyes.',
#  'honest',
#  'Sure,',
#  'Home',
#  'merciful',
#  'HIT',
#  'makes',
#  'image',
#  'abuser.',
#  'REP',
#  'good',
#  'history',
#  'SHELVES,',
#  '“Hybern.”',
#  'fail',
#  'always',
#  'meeting!!',
#  'home.',
#  'never',
#  'king,',
#  'War',
#  'remove',
#  'terrible',
#  'bisexual',
#  'BI',
#  'protagonist!',
#  'paints?',
#  'WORST',
#  'forms,',
#  'shouldn’t',
#  'got',
#  'thousand',
#  'reason.”\r\n“It',
#  'series?\r\nOH',
#  'any',
#  'blow',
#  'by',
#  'body',
#  'Elain,',
#  'review,',
#  'want',
#  'high',
#  'Guy.',
#  'kill',
#  'quest',
#  'Heroism',
#  'LEVEL',
#  'did',
#  'upsetting.',
#  'extremely',
#  '(and',
#  'villain.\r\nThat’s',
#  'didn’t',
#  'outta',
#  'Colin',
#  'Draco',
#  'instead',
#  '“to',
#  'at',
#  '45,',
#  'Family',
#  'in',
#  'prevented',
#  'Between',
#  'bad',
#  'his',
#  'feminist,',
#  'then',
#  'Eris',
#  'them,',
#  'people,',
#  'Finally',
#  '“suckable”',
#  'entire',
#  'months.',
#  'needed',
#  'safer',
#  'refers',
#  'show',
#  'arrived.\r\nLike',
#  'WHATEVER',
#  'moments',
#  'front',
#  'fifteen',
#  'revenge',
#  'cry.',
#  'page',
#  'roles.',
#  'time;',
#  'insult',
#  'satisfied',
#  'is',
#  'BANTER?',
#  'her',
#  'letting',
#  'three',
#  'amusement',
#  'opportunity',
#  'blah,',
#  '(or',
#  'civilized',
#  'soul,',
#  'apologists',
#  'they’d',
#  'boring.',
#  'between',
#  'on.',
#  'just...so',
#  'expected',
#  'already',
#  'catch',
#  'pointed',
#  'cannot.\r\nAlso,',
#  'extraordinaire,',
#  'passage.',
#  'awful.',
#  'impress',
#  'INSANE',
#  'find',
#  'hilarious.',
#  'anger',
#  'Emma)',
#  'LIKE',
#  'been',
#  'LAUGHTER',
#  'land',
#  'telling',
#  'powers,',
#  'ACOTAR,',
#  'I’ve',
#  'side',
#  'girl...she',
#  'order',
#  'schedule,',
#  'Almost.',
#  'allow',
#  'extends',
#  'insane',
#  'I’m',
#  'right???',
#  'Men,',
#  'heading',
#  'my',
#  'Morrigan',
#  'YA',
#  'Bridget',
#  '2017:',
#  'Because',
#  'entirely.\r\nNearly',
#  'poisoned',
#  'reason',
#  'WRITING',
#  'shock',
#  'many',
#  'ellipses',
#  'man',
#  'felt',
#  'AZRIEL.”\r\nTruly',
#  'leading',
#  'said',
#  'And',
#  'forces',
#  'best,',
#  'attempt',
#  'REPLACE',
#  'word',
#  'gesture”',
#  'like,',
#  'saying',
#  'dialogue',
#  'bet.)',
#  'X-rated,',
#  '“wow',
#  'though.',
#  'LISTING',
#  'category',
#  'also',
#  'motivational',
#  '2)',
#  'Mor,',
#  'rumor',
#  'about',
#  'it.\r\nIt’s',
#  'Rhysand',
#  'you’re',
#  'except',
#  'gets',
#  'INSPIRE',
#  'words',
#  'tucking',
#  'never,',
#  'reader',
#  'evidence',
#  'consensus:',
#  'world.”\r\n“I',
#  '“people”?',
#  'on,',
#  'fury”',
#  'he',
#  'feminist',
#  'writing',
#  'avert',
#  'anyway).\r\nBecause,',
#  'surprised',
#  'bi.\r\nSo',
#  'all.',
#  'book?',
#  'section',
#  'powerful',
#  'look',
#  'dumps,',
#  'cringe',
#  '(less)',
#  'LANGUAGE\r\nExcept',
#  'him.\r\nAnd',
#  'paste',
#  'much',
#  'JUST',
#  'this,',
#  'mind',
#  'little',
#  'book.\r\nTWO.\r\nHUNDRED.\r\nAND.\r\nTWO.\r\nhttps://emmareadstoomuch.wordpress.co...\r\nThat',
#  'motivation',
#  'name',
#  'trying',
#  'adieu',
#  'female',
#  'WRONG,',
#  'and',
#  'joy',
#  'mean.',
#  'darkest',
#  'Damaged',
#  'ties',
#  'ungodly',
#  'Actually,',
#  'very',
#  'that.',
#  'example.',
#  'Tamlin,',
#  'quite',
#  'someone',
#  'dumb.',
#  'Luckily,',
#  'last',
#  'unforgivable',
#  'evil-villain-revenge',
#  'battle,',
#  'Soup',
#  'although...maybe',
#  'reading',
#  'perusal',
#  'Wonderful.',
#  'Unsurprisingly,',
#  'characters.)',
#  'humans',
#  'CRUSH',
#  'cool,',
#  'TALK.\r\nBut',
#  'action.',
#  'lot',
#  'incapable',
#  'Once.',
#  'info',
#  'bounds',
#  'feat.',
#  'does',
#  'responsible',
#  '“man',
#  'seriously:',
#  'instantly*”\r\nYES.',
#  'world).',
#  'breaking',
#  'memo.',
#  'persnickety,',
#  'unpleasant,',
#  'Save',
#  'an',
#  'On',
#  'what?',
#  'THINGS.',
#  'roommates',
#  'spilling',
#  'WHO',
#  'day.”',
#  'Manson,',
#  'meeting',
#  'negotiations',
#  '“vulgar',
#  '(Feyre,',
#  'interprets',
#  'feel',
#  'GLORIFIED',
#  'Seven',
#  'top',
#  'Maas',
#  'unloved',
#  'confused,',
#  'straight,',
#  'all,',
#  'heard',
#  'abusers',
#  'therefore,',
#  'whatever.)',
#  'indulging',
#  'books',
#  'WHAT.',
#  'enough',
#  'remarkably',
#  'happened.\r\nBottom',
#  'says',
#  'change',
#  'best',
#  'speech',
#  'OR',
#  'base',
#  'out',
#  'lifetime)',
#  'smut.\r\nI’m',
#  'it’s',
#  'Long',
#  'chicken',
#  'over.\r\nReview',
#  '(At',
#  'copy',
#  'motion',
#  '*shows',
#  'buttercup.',
#  'Night',
#  'real',
#  'publish',
#  'dull,',
#  'thing',
#  ':',
#  'traps',
#  'dating',
#  'something',
#  'copyedit',
#  'apart,',
#  'smart',
#  '“too',
#  'guy,”',
#  'author',
#  'ever',
#  'prefers',
#  'Number',
#  'WHY',
#  'her.\r\nMorrigan,',
#  'almost',
#  'call',
#  'unequal',
#  'most',
#  'clear',
#  'actual,',
#  'categories',
#  'wanted',
#  'now',
#  '“Chicken',
#  'series,',
#  'lord',
#  'weren’t',
#  'Really',
#  'tend',
#  'brother,',
#  'hand,',
#  'romantic',
#  'countless',
#  'whether',
#  'WERE',
#  'sex',
#  'do',
#  'insists',
#  'lets',
#  'what.',
#  'laptop',
#  'happens',
#  'hope',
#  'thanks.\r\nThis',
#  'hours',
#  'you’ve',
#  'sit-down',
#  'strength',
#  'own.\r\nI',
#  'no?\r\nAlso,',
#  'characters',
#  'occupied',
#  'Nesta,',
#  'sitcoms',
#  'sickness.',
#  '“That',
#  'attentively',
#  'had',
#  'I',
#  'Hugh',
#  'There’s',
#  'response',
#  'goes',
#  'sexuality',
#  'nothing',
#  'entitled',
#  'bisexuality.',
#  'Renee',
#  'movement',
#  'finally',
#  'identical',
#  'y’know,',
#  'based',
#  'doing',
#  'myself',
#  'attempting',
#  'FINISH',
#  'pretending',
#  'Abuse',
#  'endless',
#  'must',
#  'angrier.\r\nAnd',
#  '“painting”',
#  'uses',
#  'coffee',
#  'established',
#  'means',
#  'They',
#  'then,',
#  'better:',
#  'much-anticipated',
#  'women.',
#  'within',
#  'WHY.',
#  'schooler',
#  'lick',
#  'BOOK',
#  'enabler',
#  'those',
#  'SUBSTANTIVE',
#  'hundreds',
#  'certainly',
#  'win.\r\nBut',
#  'are',
#  'Azriel,',
#  'found',
#  'mine,',
#  'Diary.',
#  'Rhys,',
#  'Fast',
#  'alone',
#  'SUPPOSED',
#  'hells.”\r\n“The',
#  'ribs.',
#  'NOT',
#  'Yes,',
#  'Am',
#  'faces,',
#  'soup',
#  '(I’m',
#  'image.',
#  'motivation:',
#  'followed',
#  'it',
#  'folks.\r\nTHE',
#  'occasionally,',
#  'HAVE',
#  'this.\r\nApparently,',
#  'THAT.',
#  'constantly.',
#  '“not”',
#  'SO',
#  'Rhys',
#  'it.”\r\n“One',
#  'not.',
#  'often',
#  'we’ll',
#  'fine.',
#  'rant.',
#  'help',
#  'valiant',
#  'We’ve',
#  'nearly',
#  'nourishing',
#  'decided',
#  'matters.”\r\n“Light',
#  'was',
#  'PLOTLINE\r\nThis',
#  'scenes',
#  'Men',
#  'MONTH',
#  'amount',
#  'line',
#  'Mean',
#  'or',
#  '“females”',
#  'read',
#  'else.”\r\nI',
#  'JOKES',
#  'sent',
#  'have,',
#  'Either',
#  'read.\r\nIt’s',
#  'young',
#  'instill',
#  'women.”',
#  'It’s',
#  'actively',
#  'dumb',
#  'read.\r\n----\r\npre-review\r\nI',
#  'way',
#  'stop',
#  'The',
#  'wildly',
#  'truly',
#  'straight',
#  'he’ll',
#  'COULD',
#  'paper',
#  'Feyre’s',
#  'unanimous',
#  'THESE',
#  '(a',
#  'infinity,',
#  'buckle',
#  'example,',
#  'all.\r\nAnd',
#  'How,',
#  'Or,',
#  'sacks',
#  'why',
#  'mistakes',
#  'things.',
#  'saintly',
#  'wherein',
#  'making',
#  'over.',
#  'Morrigan.',
#  'herself',
#  'typo',
#  'rep',
#  'took',
#  'recollection).',
#  'manages',
#  'depending',
#  'same',
#  'seven',
#  'fighting',
#  '“the”',
#  'girls',
#  'If',
#  'narratives.',
#  'women?',
#  'narrow',
#  'plans',
#  'men',
#  'run',
#  'efficient.\r\nAnd',
#  'threesomes;',
#  'redemption',
#  'favorite',
#  '“Ok,',
#  'absolutely',
#  'authority',
#  'point,',
#  'women',
#  'too',
#  'actions,',
#  'POSSIBLY',
#  'no,',
#  'sense',
#  'them.',
#  'years,',
#  'SPEAKS',
#  'For',
#  'were.\r\nCassian',
#  'MANY',
#  'dropped',
#  'cannot',
#  'here,',
#  'bisexuality',
#  'respect',
#  'up.',
#  'version',
#  'bored',
#  'stopped',
#  'twelve',
#  'too,',
#  'wield',
#  'MEAN.',
#  'into',
#  'tongue',
#  'books.',
#  'stars.',
#  'hilarious',
#  'eyelids.',
#  'Cassian',
#  'from',
#  'even',
#  'male',
#  'know',
#  'Draco?',
#  'Feyre',
#  "it's",
#  'its',
#  'Do',
#  'NEARBY.',
#  'joke.',
#  'having',
#  'time',
#  'dull',
#  'ages.\r\nAnd',
#  'Reading',
#  'fan.',
#  'middle',
#  'take',
#  'convincing',
#  'world',
#  'unable',
#  'pro',
#  'AND',
#  'cheap',
#  'GOOD',
#  'successful',
#  'you,',
#  'aforementioned',
#  'adolescence?',
#  'if',
#  'off',
#  'try',
#  'child',
#  'tragic',
#  'story',
#  'Instead',
#  'As',
#  'out.\r\nBut',
#  'discussion.”\r\nSo',
#  '-”\r\nIt',
#  'incontrovertibly',
#  'out,',
#  'copious',
#  'she’ll',
#  'Meeting',
#  'A',
#  'italicizations',
#  'sad',
#  'brave',
#  'schedule',
#  'Morrigan’s',
#  'friend.',
#  'laugh',
#  'To',
#  'though',
#  'Jones’',
#  'question',
#  'army',
#  'goddamn',
#  'that',
#  'term',
#  'lines.',
#  'Val',
#  'surgery',
#  'lord/commander/boss.)\r\nPlus,',
#  'we',
#  'repetitive',
#  'appeal.',
#  'millennium,',
#  'packed',
#  'activists',
#  'year.\r\nFor',
#  'IS',
#  'anything',
#  'diverse',
#  'come\r\n----\r\ncurrently-reading',
#  'Ken',
#  'more',
#  'entirely',
#  'of',
#  'tired”',
#  'war,',
#  'and,',
#  'YA???',
#  '“faceable,”',
#  'YOU',
#  'OPPOSITE',
#  'feeling',
#  'purely',
#  'hip',
#  'YES,',
#  'dump.',
#  'praying',
#  'hero',
#  'sh*tty',
#  'You',
#  'playing',
#  'rivals',
#  'watching',
#  'expect',
#  'Manson',
#  'definitely',
#  'cycle',
#  'piece',
#  'tragedy',
#  'suffering:',
#  'it,',
#  'narrows',
#  'THIS',
#  'artistic',
#  'it.”',
#  'pesky',
#  'females',
#  'Unfortunately,',
#  'DO',
#  'nomer',
#  'And,',
#  'Powerful',
#  'second',
#  'make,',
#  'said,',
#  'point',
#  'cliché,',
#  'ways:',
#  'what,',
#  'winnowing',
#  'Nesta',
#  'refreshing.',
#  'anticipate',
#  'hard,',
#  'won’t',
#  'keep',
#  'Azriel',
#  'entertainment',
#  'We',
#  'Anyway',
#  'Gang',
#  'she’s',
#  'back,',
#  'TO',
#  'IT',
#  'military',
#  'OF',
#  'calling',
#  '“She',
#  'prayed',
#  'triangle.',
#  'personification',
#  'still',
#  'Why',
#  'century',
#  'himself',
#  'gave',
#  'ACTUAL',
#  'd*ck.',
#  'things.\r\nTHE',
#  'TALK.\r\nPLOTLINE?',
#  'might',
#  'going',
#  'third',
#  'choose',
#  'is,',
#  'responds,',
#  'scream',
#  '“male.”\r\nWomen',
#  'him',
#  'a',
#  'family',
#  'could',
#  'lol.”\r\nIRRELEVANT',
#  'ass',
#  "didn't",
#  'Soul”)',
#  'as',
#  'DAEMATI',
#  'love',
#  'meeting.',
#  'remarkable',
#  'life',
#  'so',
#  'for,',
#  'f*cking',
#  '(even',
#  'fresh',
#  'somehow',
#  'Rhysand’s',
#  'become',
#  'nonstop',
#  'eyes',
#  'MEANS',
#  'powers.”',
#  'without',
#  'do.\r\nTHE',
#  'times,',
#  'something,',
#  'both',
#  'situation?',
#  'counted',
#  'harder',
#  'omg...who',
#  'possible.\r\nWHAT',
#  '(of',
#  'made',
#  'around',
#  'spends',
#  '“You',
#  'sticking',
#  'amusement.\r\n“Leave',
#  'doll:',
#  'can’t',
#  'prettiness',
#  'kingdom,',
#  'clothes',
#  '“women”?',
#  'seemingly',
#  'incredibly,',
#  'Hard',
#  'relationships',
#  'genuinely',
#  'SUCKS,',
#  'FANTASY',
#  'confronts',
#  'Lucien’s',
#  'king',
#  'there',
#  'evil',
#  'interesting',
#  "You're",
#  'screaming.\r\nSpeaking',
#  'work',
#  'another.',
#  'you.\r\nSo',
#  'HAPPENS',
#  'WHICH',
#  'everyone',
#  'stupid.\r\nBut',
#  'bidding',
#  'day',
#  'Eris,',
#  'That',
#  'USES',
#  'right,',
#  '“we”',
#  'far.',
#  'you.”\r\n“I',
#  'CLICHES\r\nAs',
#  'REP\r\nBut',
#  'She',
#  'DOING.',
#  'daddy,',
#  'Cassian,',
#  'every',
#  'CHARACTER',
#  'than',
#  'force',
#  'sadness.\r\nTruly,',
#  'rating.',
#  'how',
#  'brilliant',
#  'Morrigan.”',
#  'powers',
#  '“OH',
#  'it.\r\nEveryone',
#  '700',
#  'interests',
#  '“that’s',
#  'Cassandra',
#  'your',
#  'knew',
#  'other',
#  'omg-he’s-just-trying-to-do-right-he-didn’t-know-any-better',
#  'LEVEL\r\nI',
#  'SJM',
#  'boy',
#  'good.\r\nLET’S',
#  'twenty-eight',
#  'may',
#  'think',
#  'book,',
#  'paint',
#  'blame',
#  'boring',
#  'ladies',
#  'fine!\r\nSo',
#  'wasn’t',
#  'Listen',
#  'singular',
#  'Twelve',
#  'AT',
#  'for',
#  'Except',
#  'WITH.',
#  'equally',
#  ...}

# %%
word2vec_sg.save("word2vec_model")
w2v = Word2Vec.load("word2vec_model")

# %%
book_data = []
for key,book in enumerate(dataset['review_vocabs']):
    if len(book) == 0:
        print(book, key)
    feature_vector = np.zeros((100,), dtype="float32")
    nwords = len(book)
    for token in book:
        feature_vector = np.add(feature_vector, w2v[token])
    
    feature_vector = np.divide(feature_vector, nwords)
    book_data.append({'book': data['book_title'][key],
                      'tags':book, 'vector':feature_vector})

# %%
book_vector_df = pd.DataFrame(book_data,columns=['book', 
                                                 'tags', 
                                                 'vector'])
book_vector_df[:10]
# Out:
#                         book  \
# 0  A Court of Wings and Ruin
# 1  A Court of Wings and Ruin
# 2  A Court of Wings and Ruin
# 3  A Court of Wings and Ruin
# 4  A Court of Wings and Ruin
# 5  A Court of Wings and Ruin
# 6  A Court of Wings and Ruin
# 7  A Court of Wings and Ruin
# 8  A Court of Wings and Ruin
# 9  A Court of Wings and Ruin
#
#                                                 tags  \
# 0  {certain, through, males., SCREAM, innocuous, ...
# 1  {getting, hoo, THAT, respect, fault, feysand,,...
# 2  {getting, gods-given, THAT, certain, possible,...
# 3  {getting, spoiler), up., bored, fandom, Rhys—i...
# 4  {“skin, disappointment, dislike, they/won't, s...
# 5  {getting, Because, RHYS’s, character, certain,...
# 6  {LOVED, happy., book!\r\nOMG!, certain, up., F...
# 7  {respect, wasn’t, singular, noting, for.\r\nI,...
# 8  {however,, I, not, A, favorite, I'll, reason, ...
# 9  {I, hope, was, enthralling, with, hoped, the, ...
#
#                                               vector
# 0  [-0.5484056, -0.32977834, 0.30974036, -0.10943...
# 1  [-0.5619967, -0.33631402, 0.34566084, -0.12547...
# 2  [-0.63494176, -0.39416352, 0.37172803, -0.1429...
# 3  [-0.6138561, -0.3726921, 0.4036188, -0.1553327...
# 4  [-0.6977611, -0.35235217, 0.42411292, -0.16556...
# 5  [-0.6856276, -0.44225043, 0.46301648, -0.20481...
# 6  [-0.6835308, -0.46053916, 0.4386459, -0.180559...
# 7  [-0.67322505, -0.45294026, 0.47940415, -0.1340...
# 8  [-0.6601552, -0.43317392, 0.42666966, -0.15526...
# 9  [-0.6939005, -0.383431, 0.37702027, -0.2024100...

# %%
book_vector_df.shape
# Out:
# (21559, 3)

# %% [markdown]
# ## 5. Book Recommendation

# %%
words_in_vocab= set(word2vec_sg.wv.index2word)

# %%
def get_cosine_similarity(row, search_vector):
    try:
        cosine_similarity = np.dot(row['vector'], search_vector)/linalg.norm(row['vector'])/linalg.norm(search_vector)
        return cosine_similarity
    except Exception as e:
        raise e

# %%
# Mencari buku dengan judul "A Crown of Wishes"
book = input('Buku yang dicari: ')
# Out:
# Buku yang dicari: A Crown of Wishes

# %%
book
# Out:
# 'A Crown of Wishes'

# %%
for i, j in enumerate(dataset['book_title']):
    if j == book:
        index_similar_book = i

search_query = dataset['review_vocabs'][index_similar_book]

# %%
search_vector = np.zeros((100,), dtype="float32")
for tag in search_query:
    if tag in words_in_vocab:
        search_vector = np.add(search_vector, w2v[tag])
        
book_vector_df['cosine_similarity'] = book_vector_df.apply(get_cosine_similarity,
                                                           axis=1, args=(search_vector,))

# %%
df = book_vector_df.sort_values(by='cosine_similarity', ascending=False)[:10]

# %%
print("Maka buku yang direkomendasikan berdasarkan buku {0} adalah :".format(book))
df[['book', 'cosine_similarity']]
# Out:
# Maka buku yang direkomendasikan berdasarkan buku A Crown of Wishes adalah :
#                             book  cosine_similarity
# 5740           A Crown of Wishes           1.000000
# 9330             The Song Rising           0.997565
# 5722           A Crown of Wishes           0.997554
# 8733            The Duchess Deal           0.997545
# 13840                   Raw Need           0.997517
# 14210              Real Good Man           0.997508
# 15347  A Conspiracy in Belgravia           0.997464
# 4673            What to Say Next           0.997358
# 12082            Assassin's Fate           0.997307
# 5720           A Crown of Wishes           0.997301
